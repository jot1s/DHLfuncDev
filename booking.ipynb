# %%
import requests

url = "https://api-mock.dhl.com/mydhlapi/shipments/1140605690/tracking"

headers = {
	"Message-Reference": "",
	"Message-Reference-Date": "",
	"Accept-Language": "eng",
	"Plugin-Name": "",
	"Plugin-Version": "",
	"Shipping-System-Platform-Name": "",
	"Shipping-System-Platform-Version": "",
	"Webstore-Platform-Name": "",
	"Webstore-Platform-Version": "",
	"Authorization": ""
}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"status":500,"title":"Internal Server Error","detail":"The server encountered an unexpected condition that prevented it from fulfilling the request."}

# %%
import requests

trackingNumber = 6113737884
#url = "https://api-eu.dhl.com/track/shipments"
url = 'https://express.api.dhl.com/mydhlapi/test '

headers = {
    'Accept': 'application/json',
    'DHL-API-Key': 'apI1hL9eB7gG7b'
    }
payload = {
    'trackingNumber': str(trackingNumber),
    'service': 'express'
}

# This url is for testing 
#url = 'https://httpbin.org/get'
resp = requests.get(url, params=payload, headers=headers)

print(resp.text)
# Out:
# {
#
#    "reasons": [{"msg" : "Invalid Credentials"}],
#
#    "details": {
#     "msgId": "Id-2807ef65ee77964b676c4db1"
#   }
#
# }

# %%
import requests

trackingNumber = 6113737884
#url = "https://api-eu.dhl.com/track/shipments"
url = 'https://express.api.dhl.com/mydhlapi/test '

headers = {
    'Accept': 'application/json',
    'DHL-API-Key': 'apI1hL9eB7gG7b'
    }
payload = {
    'trackingNumber': str(trackingNumber),
    'service': 'express'
}

# This url is for testing 
#url = 'https://httpbin.org/get'
resp = requests.get(url, params=payload, headers=headers)

print(resp.text)

# %%
data = resp.json()

# 提取需要的信息
desired_info = data['shipments'][0]['events'][0]['description']
end_time=data['shipments'][0]['events'][0]['timestamp']
start_time=data['shipments'][0]['events'][-1]['timestamp']
status = data['shipments'][0]['status']['status']
origin = data['shipments'][0]['origin']['address']['addressLocality']
destination = data['shipments'][0]['destination']['address']['addressLocality']
print(status)
print(origin)
print(destination)
# print(end_time)
# print(start_time)
# Out:
# delivered
# MUNICH - GERMANY
# CAMBRIDGE - UK

# %%
from datetime import datetime

# Parse ISO formatted date-time
end_datetime = datetime.strptime(end_time, "%Y-%m-%dT%H:%M:%S")
start_datetime = datetime.strptime(start_time, "%Y-%m-%dT%H:%M:%S")

# Format as Excel-compatible date and time strings
# excel_date = parsed_datetime.strftime("%Y-%m-%d")
# excel_time = parsed_datetime.strftime("%H:%M:%S")
duration_time = end_datetime - start_datetime

print("Excel Date:", excel_date)
print("Excel Time:", excel_time)
print(duration_time)
# Out:
# Excel Date: 2024-03-06
# Excel Time: 11:37:00
# 1 day, 20:56:00

# %%
import requests

url = "https://api-mock.dhl.com/mydhlapi/pickups"

payload = {
	"plannedPickupDateAndTime": "2024-03-18T12:00:31GMT+01:00",
	"closeTime": "14:00",
	"location": "reception",
	"locationType": "residence",
	"accounts": [
		{
			"typeCode": "receiver",
			"number": "147693222" 
		}
	],
	"specialInstructions": [
		{
			"value": "please ring door bell",
			"typeCode": "TBD"
		}
	],
	"remark": "string",
	"customerDetails": {
		"shipperDetails": {
			"postalAddress": {
				"postalCode": "97082",
				"cityName": "Würzburg",
				"countryCode": "DE",
				"addressLine1": "Julius-von-Sachs Platz 2",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				
			},
			"contactInformation": {
				"email": "matthias.freund@stud-mail.uni-wuerzburg.de",
				"phone": "+499313184324",
				"companyName": "Julius-von-Sachs Institute for Biosciences",
				"fullName": " Kenji Fukushima"
			}
		},
		"receiverDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "München",
				"countryCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				"countyName": "Planegg"
			},
			"contactInformation": {
				"email": "shipping@novogene.com",
				"phone": "+498937040454",
				#"mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			}
		},
		"bookingRequestorDetails": {
			"postalAddress": {
                "postalCode": "82152",
				"cityName": "München",
				"countryCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				"countyName": "Planegg"

			},
			"contactInformation": {
				"contactInformation": {
				"email": "shipping@novogene.com",
				"phone": "+498937040454",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			}
		},
		"pickupDetails": {
			"postalAddress": {
                "postalCode": "97082",
				"cityName": "Würzburg",
				"countryCode": "DE",
				"addressLine1": "Julius-von-Sachs Platz 2",
				"addressLine2": "addres2",
				"addressLine3": "addres3",

			},
			"contactInformation": {
				"email": "matthias.freund@stud-mail.uni-wuerzburg.de",
				"phone": "+499313184324",
				"companyName": "Julius-von-Sachs Institute for Biosciences",
				"fullName": " Kenji Fukushima"
			}
		}
	},
	"shipmentDetails": [
		{
			"productCode": "string",
			"localProductCode": "str",
			"accounts": [
				{
					"typeCode": "receiver",
					"number": "147693222" 
				}
			],
			"valueAddedServices": [
				{
					"serviceCode": "II",
					"localServiceCode": "II",
					"value": 100,
					"currency": "GBP",
					"method": "cash"
				}
			],
			"isCustomsDeclarable": True,
			"declaredValue": 150,
			"declaredValueCurrency": "CZK",
			"unitOfMeasurement": "metric",
			"shipmentTrackingNumber": "123456790",
			"packages": [
				{
					"typeCode": "3BX",
					"weight": 10.5,
					"dimensions": {
						"length": 25,
						"width": 35,
						"height": 15
					}
				}
			]
		}
	]
}
headers = {
    'Accept': 'application/json',
    'DHL-API-Key': 'apI1hL9eB7gG7b'
    }
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)

# %%
{"shipments":
 [{"id":"6113737884","service":"express",
"origin":{"address":{"addressLocality":"MUNICH - GERMANY"},"servicePoint":{"url":"http://www.dhl.com/en/de/country_profile.html","label":"Origin Service Area"}},
"destination":{"address":{"addressLocality":"CAMBRIDGE - UK"},"servicePoint":{"url":"http://www.dhl.co.uk/en/country_profile.html","label":"Destination Service Area"}},
"status":{"timestamp":"2024-03-05T01:19:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"statusCode":"transit","status":"transit","description":"Scheduled to depart on the next planned movement"},"details":{"product":{"productCode":"Q","productName":"MEDICAL EXPRESS"},"proofOfDelivery":{"documentUrl":"https://proview.dhl.com/proview/adhocnotify?id=kqWHAC7y5BL6vQCVmfJxY5FIIeeuSJqyq5s8AKmHCQk%3D&appuid=2oqOxsuQWoQP3%2BCi9modJA%3D%3D&locale=en&token=N1YbO0ozrbnmFdHTMDnGH7A0V4qA124LF2O22zX5298%3D","signatureUrl":"https://proview.dhl.com/proview/adhocnotify?id=kqWHAC7y5BL6vQCVmfJxY5FIIeeuSJqyq5s8AKmHCQk%3D&appuid=2oqOxsuQWoQP3%2BCi9modJA%3D%3D&locale=en&token=N1YbO0ozrbnmFdHTMDnGH7A0V4qA124LF2O22zX5298%3D"},"proofOfDeliverySignedAvailable":false,"totalNumberOfPieces":1,"pieceIds":["JD014600011396901891"]},
"events":
[{"timestamp":"2024-03-05T01:19:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},
"description":"Scheduled to depart on the next planned movement",
"pieceIds":["JD014600011396901891"]},
{"timestamp":"2024-03-05T01:01:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"description":"Shipment is on hold","pieceIds":["JD014600011396901891"]},{"timestamp":"2024-03-04T20:54:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"description":"Processed at MUNICH - GERMANY","pieceIds":["JD014600011396901891"]},{"timestamp":"2024-03-04T20:36:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"description":"Arrived at DHL Sort Facility  MUNICH - GERMANY","pieceIds":["JD014600011396901891"]},{"timestamp":"2024-03-04T20:14:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"description":"Shipment has departed from a DHL facility MUNICH - GERMANY","pieceIds":["JD014600011396901891"]},{"timestamp":"2024-03-04T14:41:00","location":{"address":{"addressLocality":"MUNICH - GERMANY"}},"description":"Shipment picked up","pieceIds":["JD014600011396901891"]}]}]}

# %%
import requests

url = "https://api-mock.dhl.com/mydhlapi/shipments" ### url 输入



payload = {
	"plannedShippingDateAndTime": "2024-03-20T12:00:31GMT+01:00", ### 时间格式输入
	"pickup": {
		"isRequested": True, #qujian否？
		"closeTime": "14:00",
		"location": "reception",
		"specialInstructions": [
			{
				"value": "isolated DNA, 5kg ice dry inside",##安置ICE DRY 之类的
				"typeCode": "TBD"
			}
		],
		"pickupDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				# "countyName": "Central Bohemia",
				# "provinceName": "Bayern",
				"countryName": "Germany"

			},
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			# "registrationNumbers": [
			# 	{
			# 		"typeCode": "VAT",
			# 		"number": "CZ123456789",
			# 		"issuerCountryCode": "CZ"
			# 	}
			# # ],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		},
		"pickupRequestorDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				# "countyName": "Central Bohemia",
				# "provinceName": "Bayern",
				"countryName": "Germany"

			},
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			# "registrationNumbers": [
			# 	{
			# 		"typeCode": "VAT",
			# 		"number": "CZ123456789",
			# 		"issuerCountryCode": "CZ"
			# 	}
			# ],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		}
	},
	"productCode": "D", #这边需要加入判断条件，是否交税，是否报关
	"localProductCode": "D",
	"getRateEstimates": False,
	"accounts": [
		{
			"typeCode": "receiver", ###### 账户信息在这里修改
			"number": "147693222"
		}
	],
	"valueAddedServices": [
		{
			"serviceCode": "II",
			"value": 100,
			"currency": "EURO",
			# "method": "cash",
			"dangerousGoods": [
				{
					"contentId": "908",
					"dryIceTotalNetWeight": 6, ### 这里加入需要加入干冰的数量
					"customDescription": "1 package Lithium ion batteries in compliance with Section II of P.I. 9661", ### 这里加入危险信息的描述
					"unCodes": [1234] ### 这里需要重点查看
                    
				}
			]
		}
	],
	"outputImageProperties": {
		"printerDPI": 300, ###这边可以不用动
		"customerBarcodes": [
			{
				"content": "barcode content",
				"textBelowBarcode": "text below barcode",
				"symbologyCode": "93"
			}
		],
		"customerLogos": [
			{
				"fileFormat": "PNG",
				"content": "base64 encoded image"
			}
		],
		"encodingFormat": "pdf",
		"imageOptions": [
			{
				"typeCode": "label",
				"templateName": "ECOM26_84_001",
				"isRequested": True,
				"hideAccountNumber": False,
				"numberOfCopies": 1,
				"invoiceType": "commercial",
				"languageCode": "eng",
				"languageCountryCode": "br",
				"languageScriptCode": "Latn",
				"encodingFormat": "png",
				"renderDHLLogo": False,
				"fitLabelsToA4": False,
				"labelFreeText": "string",
				"labelCustomerDataText": "string",
				"shipmentReceiptCustomerDataText": "string"
			}
		],
		"splitTransportAndWaybillDocLabels": True,
		"allDocumentsInOneImage": True,
		"splitDocumentsByPages": True,
		"splitInvoiceAndReceipt": True,
		"receiptAndLabelsInOneImage": True
	},
	"customerReferences": [
		{
			"value": "Customer reference",
			"typeCode": "CU"
		}
	],
	"identifiers": [
		{
			"typeCode": "shipmentId", #这里的ID 还需要更改
			"value": "1234567890",
			"dataIdentifier": "00"
		}
	],
	"customerDetails": {
		"shipperDetails": { # 发件人信息要注意！！！
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				"countyName": "Planegg",
				# "provinceName": "Central Bohemia",
				"countryName": "Germany"
			},
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			"registrationNumbers": [
				{
					"typeCode": "VAT",
					"number": " DE363337480",
					"issuerCountryCode": "DE"
				}
			],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		},
		"receiverDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				"countyName": "Planegg",
				# "provinceName": "Central Bohemia",
				"countryName": "Germany"
			},
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			"registrationNumbers": [
				{
					"typeCode": "VAT",
					"number": " DE363337480",
					"issuerCountryCode": "DE"
				}
			],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		},
		"buyerDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				# "countyName": "Central Bohemia",
				# "provinceName": "Bayern",
				"countryName": "Germany"
			},
            
			###########
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			"registrationNumbers": [
				{
					"typeCode": "VAT",
					"number": " DE363337480",
					"issuerCountryCode": "DE"
				}
			],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		},
		# "importerDetails": {
		# 	"postalAddress": {
		# 		"postalCode": "14800",
		# 		"cityName": "Prague",
		# 		"countryCode": "CZ",
		# 		"provinceCode": "CZ",
		# 		"addressLine1": "V Parku 2308/10",
		# 		"addressLine2": "addres2",
		# 		"addressLine3": "addres3",
		# 		"countyName": "Central Bohemia",
		# 		"provinceName": "Central Bohemia",
		# 		"countryName": "Czech Republic"
		# 	},
		# 	"contactInformation": {
		# 		"email": "that@before.de",
		# 		"phone": "+1123456789",
		# 		"mobilePhone": "+60112345678",
		# 		"companyName": "Company Name",
		# 		"fullName": "John Brew"
		# 	},
		# 	"registrationNumbers": [
		# 		{
		# 			"typeCode": "VAT",
		# 			"number": "CZ123456789",
		# 			"issuerCountryCode": "CZ"
		# 		}
		# 	],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			# "typeCode": "business"
		# },
        #### 进出口涉及国际物流， 英国 中国
		# "exporterDetails": { ### 进出口 涉及
		# 	"postalAddress": {
		# 		"postalCode": "14800",
		# 		"cityName": "Prague",
		# 		"countryCode": "CZ",
		# 		"provinceCode": "CZ",
		# 		"addressLine1": "V Parku 2308/10",
		# 		"addressLine2": "addres2",
		# 		"addressLine3": "addres3",
		# 		"countyName": "Central Bohemia",
		# 		"provinceName": "Central Bohemia",
		# 		"countryName": "Czech Republic"
		# 	},
		# 	"contactInformation": {
		# 		"email": "that@before.de",
		# 		"phone": "+1123456789",
		# 		"mobilePhone": "+60112345678",
		# 		"companyName": "Company Name",
		# 		"fullName": "John Brew"
		# 	},
		# 	"registrationNumbers": [
		# 		{
		# 			"typeCode": "VAT",
		# 			"number": "CZ123456789",
		# 			"issuerCountryCode": "CZ"
		# 		}
		# 	],
		# 	"bankDetails": [
		# 		{
		# 			"name": "Russian Bank Name",
		# 			"settlementLocalCurrency": "RUB",
		# 			"settlementForeignCurrency": "USD"
		# 		}
		# 	],
		# 	"typeCode": "business"
		# },
		# "sellerDetails": {
		# 	"postalAddress": {
		# 		"postalCode": "14800",
		# 		"cityName": "Prague",
		# 		"countryCode": "CZ",
		# 		"provinceCode": "CZ",
		# 		"addressLine1": "V Parku 2308/10",
		# 		"addressLine2": "addres2",
		# 		"addressLine3": "addres3",
		# 		"countyName": "Central Bohemia",
		# 		"provinceName": "Central Bohemia",
		# 		"countryName": "Czech Republic"
		# 	},
		# 	"contactInformation": {
		# 		"email": "that@before.de",
		# 		"phone": "+1123456789",
		# 		"mobilePhone": "+60112345678",
		# 		"companyName": "Company Name",
		# 		"fullName": "John Brew"
		# 	},
		# 	"registrationNumbers": [
		# 		{
		# 			"typeCode": "VAT",
		# 			"number": "CZ123456789",
		# 			"issuerCountryCode": "CZ"
		# 		}
		# 	],
		# 	"bankDetails": [
		# 		{
		# 			"name": "Russian Bank Name",
		# 			"settlementLocalCurrency": "RUB",
		# 			"settlementForeignCurrency": "USD"
		# 		}
		# 	],
		# 	"typeCode": "business"
		# },
		"payerDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				# "countyName": "Central Bohemia",
				# "provinceName": "Bayern",
				"countryName": "Germany"
			},
			"contactInformation": {
				"email": "that@before.de",
				"phone": "+1123456789",
				"mobilePhone": "+60112345678",
				"companyName": "Company Name",
				"fullName": "John Brew"
			},
			"registrationNumbers": [
				{
					"typeCode": "VAT",
					"number": " DE363337480",
					"issuerCountryCode": "DE"
				}
			],
			# "bankDetails": [
			# 	{
			# 		"name": "Russian Bank Name",
			# 		"settlementLocalCurrency": "RUB",
			# 		"settlementForeignCurrency": "USD"
			# 	}
			# ],
			"typeCode": "business"
		},
		"ultimateConsigneeDetails": {
			"postalAddress": {
				"postalCode": "82152",
				"cityName": "Munich",
				"countryCode": "DE",
				"provinceCode": "DE",
				"addressLine1": "Am Klopferspitz 19a",
				"addressLine2": "addres2",
				"addressLine3": "addres3",
				# "countyName": "Central Bohemia",
				# "provinceName": "Bayern",
				"countryName": "Germany"

			},
			"contactInformation": {
				"email": "wentao.dou@novogene-europe.com",
				"phone": "+498937040454",
				# "mobilePhone": "+60112345678",
				"companyName": "Novogene GmbH",
				"fullName": "Logistics Team"
			},
			"registrationNumbers": [
				{
					"typeCode": "VAT",
					"number": "DE363337480",
					"issuerCountryCode": "DE"
				}
			],
			# "bankDetails": {
			# 	"typeCode": "VAT",
			# 	"number": " ",
			# 	"issuerCountryCode": "DE"
			# },
			"typeCode": "string"
		}
	},
	"content": {
		"packages": [
			{
				"typeCode": "2BP",
				"weight": 7.001,
				"dimensions": {
					"length": 20.001,
					"width": 22.001,
					"height": 20.001
				},
				"customerReferences": [
					{
						"value": "Customer reference", 
						"typeCode": "CU"
					}
				],
				"identifiers": [
					{
						"typeCode": "shipmentId",
						"value": "147693222", ###### 这边填入ID
						"dataIdentifier": "00"
					}
				],
				"description": "Piece content description",
				"labelBarcodes": [
					{
						"position": "left",
						"symbologyCode": "93",
						"content": "string",
						"textBelowBarcode": "text below left barcode"
					}
				],
				"labelText": [
					{
						"position": "left",
						"caption": "text caption",
						"value": "text value"
					}
				],
				"labelDescription": "bespoke label description"
			}
		],
		"isCustomsDeclarable": True,
		"declaredValue": 10,
		"declaredValueCurrency": "EU",
		"exportDeclaration": {
			"lineItems": [
				{
					"number": 1,
					"description": "line item description",
					"price": 10,
					"quantity": {
						"value": 1,
						"unitOfMeasurement": "BOX"
					},
					"commodityCodes": [
						{
							"typeCode": "outbound",
							"value": 851713
						}
					],
					"exportReasonType": "permanent",
					"manufacturerCountry": "EU",
					"weight": {
						"netValue": 10,
						"grossValue": 10
					},
					"isTaxesPaid": True,
					"additionalInformation": ["string"],
					# "customerReferences": [
					# 	{
					# 		"typeCode": "AFE",
					# 		"value": "custref123"
					# 	}
					# ],
					# "customsDocuments": [
					# 	{
					# 		"typeCode": "972",
					# 		"value": "custdoc456"
					# 	}
					# ],
					"preCalculatedLineItemTotalValue": 10
				}
			],
			# "invoice": {
			# 	"number": "12345-ABC",
			# 	"date": "2020-03-18",
			# 	"signatureName": "Brewer",
			# 	"signatureTitle": "Mr.",
			# 	"signatureImage": "Base64 encoded image",
			# 	"instructions": ["string"],
			# 	"customerDataTextEntries": ["string"],
			# 	"totalNetWeight": 999999999999,
			# 	"totalGrossWeight": 999999999999,
			# 	"customerReferences": [
			# 		{
			# 			"typeCode": "CU",
			# 			"value": "custref112"
			# 		}
			# 	],
			# 	"termsOfPayment": "100 days",
			# 	"indicativeCustomsValues": {
			# 		"importCustomsDutyValue": 150.57,
			# 		"importTaxesValue": 49.43,
			# 		"totalWithImportDutiesAndTaxes": [350.57]
			# 	},
			# 	"preCalculatedTotalValues": {
			# 		"preCalculatedTotalGoodsValue": 49.43,
			# 		"preCalculatedTotalInvoiceValue": 150.57
			# 	}
			# },
			# "remarks": [{"value": "declaration remark"}],
			# "additionalCharges": [
			# 	{
			# 		"value": 10,
			# 		"caption": "fee",
			# 		"typeCode": "freight"
			# 	}
			# ],
			"destinationPortName": "port details",
			"placeOfIncoterm": "port of departure or destination details",
			"payerVATNumber": "DE363337480",
			"recipientReference": "recipient reference",
			# "exporter": {
			# 	"id": "123",
			# 	"code": "EXPCZ"
			# },
			# "packageMarks": "marks",
			# "declarationNotes": [{"value": "up to three declaration notes"}],
			# "exportReference": "export reference",
			# "exportReason": "export reason",
			# "exportReasonType": "permanent",
			# "licenses": [
			# 	{
			# 		"typeCode": "export",
			# 		"value": "license"
			# 	}
			# ],
			"shipmentType": "personal",
			"customsDocuments": [
				{
					"typeCode": "972",
					"value": "custdoc445"
				}
			]
		},
		"description": "shipment description",
		"USFilingTypeValue": "12345",
		"incoterm": "DAP",
		"unitOfMeasurement": "metric"
	},
	"documentImages": [
		{
			"typeCode": "INV",
			"imageFormat": "PDF",
			"content": "base64 encoded image"
		}
	],
	"onDemandDelivery": {
		"deliveryOption": "servicepoint",
		"location": "front door",
		"specialInstructions": "ringe twice",
		# "gateCode": "1234",
		# "whereToLeave": "concierge",
		# "neighbourName": "Mr.Dan",
		# "neighbourHouseNumber": "777",
		# "authorizerName": "Newman",
		# "servicePointId": "SPL123",
		"requestedDeliveryDate": "2024-04-20"
	},
	"requestOndemandDeliveryURL": True,
	"shipmentNotification": [
		{
			"typeCode": "email",
			"receiverId": "wentao.dou@novogene-europe.com",
			"languageCode": "eng",
			"languageCountryCode": "DE",
			"bespokeMessage": "message to be included in the notification"
		}
	],
	# "prepaidCharges": [
	# 	{
	# 		"typeCode": "freight",
	# 		"currency": "CZK",
	# 		"value": 200,
	# 		"method": "cash"
	# 	}
	# ],
	"getTransliteratedResponse": False,
	"estimatedDeliveryDate": {
		"isRequested": False,
		"typeCode": "QDDC"
	},
	"getAdditionalInformation": [
		{
			"typeCode": "pickupDetails",
			"isRequested": True
		}
	],
	"parentShipment": {
		"productCode": "s",
		"packagesCount": 1
	}
}
headers = {
	"content-type": "application/json",
	# "Message-Reference": "SOME_STRING_VALUE",
	# "Message-Reference-Date": "SOME_STRING_VALUE",
	# "Plugin-Name": "SOME_STRING_VALUE",
	# "Plugin-Version": "SOME_STRING_VALUE",
	# "Shipping-System-Platform-Name": "SOME_STRING_VALUE",
	# "Shipping-System-Platform-Version": "SOME_STRING_VALUE",
	# "Webstore-Platform-Name": "SOME_STRING_VALUE",
	# "Webstore-Platform-Version": "SOME_STRING_VALUE",
	"Authorization": "Basic REPLACE_BASIC_AUTH",
    'Accept': 'application/json',
    'DHL-API-Key': 'apI1hL9eB7gG7b'
}

response = requests.request("POST", url, json=payload, headers=headers)

print(response.text)
# Out:
# {"status":500,"title":"Internal Server Error","detail":"The server encountered an unexpected condition that prevented it from fulfilling the request."}
